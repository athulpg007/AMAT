# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle

# %%
import numpy as np
from scipy import interpolate
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.patches import Polygon

# %%
# Create a planet object
planet=Planet("VENUS")
planet.h_skip = 150000.0
planet.h_low=10.0E3

# Load an nominal atmospheric profile with height, temp, pressure, density data
planet.loadAtmosphereModel('../../../atmdata/Venus/venus-gram-avg.dat', 0 , 1 ,2, 3)

# Set up a vehicle object
vehicle=Vehicle('SmallSat1', 37, 20, 0.0, 1.767, 0.0, 0.35, planet)
vehicle.setInitialState(150.0,-6.22,23.16,10.8191,89.9982,-5.30,0.0,0.0)
vehicle.setSolverParams(1E-6)
vehicle.setDragModulationVehicleParams(20, 7.5)

# Set up the drag modulation entry phase guidance parameters.
vehicle.setDragEntryPhaseParams(2.0, 20.0, 101, -200.0)

# Set the target orbit parameters.
vehicle.setTargetOrbitParams(200.0, 1800.0, 20.0)

# Define the path to atmospheric files to be used for the Monte Carlo simulations.
atmfiles = ['../../../atmdata/Venus/LAT20N.txt']

# Set up the Monte Carlo simulation for drag modulation.
# NPOS = 151, NMONTE = 200
# Target EFPA = -5.30 deg
# EFPA 1-sigma error = +/- 0.033 deg
# Nominal beta_1 = 20 kg/m2
# beta_1 1-sigma = 0.0
# guidance time step for entry = 1.0s (Freq. = 1 Hz)
# guidance time step after jettison = 1.0 s
# max. solver time step = 0.1 s
# max. time used by solver = 2400 s

vehicle.setupMonteCarloSimulationD(151, 200, atmfiles, 0 , 1, 2, 3, 4, True,
                                   -5.20,  0.0333, 20.0, 0.0,
                                    1.0, 1.0, 0.1, 2400.0)
# Run 200 trajectories
vehicle.runMonteCarloD2(100, '../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1')
# Out:
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 1, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 43, EFPA: -5.25, SIGMA: 1.00, APO : 2324.51
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 2, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 132, EFPA: -5.17, SIGMA: -0.54, APO : 1864.59
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 3, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 178, EFPA: -5.19, SIGMA: 0.23, APO : 1929.79
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 4, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 152, EFPA: -5.25, SIGMA: -1.51, APO : 2133.69
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 5, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 82, EFPA: -5.23, SIGMA: 1.03, APO : 2271.36
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 6, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 66, EFPA: -5.16, SIGMA: -0.19, APO : 1815.40
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 7, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 192, EFPA: -5.20, SIGMA: 0.21, APO : 2114.07
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 8, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 146, EFPA: -5.19, SIGMA: 2.33, APO : 1970.76
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 9, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 76, EFPA: -5.23, SIGMA: -0.56, APO : 2210.89
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 10, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 89, EFPA: -5.24, SIGMA: -1.88, APO : 1571.03
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 11, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 21, EFPA: -5.22, SIGMA: -0.35, APO : 2534.71
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 12, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 147, EFPA: -5.15, SIGMA: 0.38, APO : 1823.84
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 13, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 173, EFPA: -5.19, SIGMA: 0.30, APO : 1712.53
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 14, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 164, EFPA: -5.21, SIGMA: -1.51, APO : 2089.02
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 15, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 183, EFPA: -5.20, SIGMA: 0.67, APO : 2106.67
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 16, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 137, EFPA: -5.18, SIGMA: -0.08, APO : 1805.56
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #:
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 93, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 8, EFPA: -5.23, SIGMA: 1.90, APO : 2732.17
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 94, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 89, EFPA: -5.14, SIGMA: -0.11, APO : 1768.23
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 95, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 60, EFPA: -5.18, SIGMA: -1.08, APO : 1868.45
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 96, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 155, EFPA: -5.23, SIGMA: -0.06, APO : 2273.96
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 97, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 179, EFPA: -5.28, SIGMA: 3.15, APO : 1285.70
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 98, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 121, EFPA: -5.24, SIGMA: -1.24, APO : 1791.23
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 99, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 14, EFPA: -5.21, SIGMA: 0.08, APO : 2128.48
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1, RUN #: 100, PROF: ../../../atmdata/Venus/LAT20N.txt, SAMPLE #: 46, EFPA: -5.22, SIGMA: 0.05, APO : 2413.60

# %%
p1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/terminal_periapsis_arr.txt')
x1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/terminal_apoapsis_arr.txt')
y1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/acc_net_g_max_arr.txt')
z1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/q_stag_max_arr.txt')
h1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/heatload_max_arr.txt')
u1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/periapsis_raise_DV_arr.txt')
v1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/venus/MCBX1/apoapsis_raise_DV_arr.txt')

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].hist(x1, bins=20, color='xkcd:periwinkle')
axes[0].set_xlabel('Apoapsis altitude x, km', fontsize=10)
axes[0].set_ylabel('Number of cases', fontsize=10)

axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)


axes[1].plot(p1, x1, 'bo', markersize=5, mfc='None')

axes[1].set_xlabel('Periapsis altitude, km',fontsize=10)
axes[1].set_ylabel('Apoapsis altitude, km', fontsize=10)


axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)

for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].plot(y1, z1, 'ro', markersize=5, mfc='None')
axes[0].set_xlabel('Peak deceleration, Earth g', fontsize=10)
axes[0].set_ylabel('Peak stagnation-point heat rate, '+r'$W/cm^2$', fontsize=10)
axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)

axes[1].plot(z1, h1, 'go', markersize=5, mfc='None')
axes[1].set_xlabel('Peak stagnation-point heat rate, '+r'$W/cm^2$', fontsize=10)
axes[1].set_ylabel('Peak stagnation-point heat load, '+r'$kJ/cm^2$', fontsize=10)

axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)



for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].hist(u1, bins=10, color='xkcd:periwinkle')
axes[0].set_xlabel('Periapse raise '+r'$\Delta V$'+', m/s', fontsize=10)
axes[0].set_ylabel('Number of cases', fontsize=10)
axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)

axes[1].hist(np.abs(v1), bins=10, color='xkcd:orange')
axes[1].set_xlabel('Apoapsis correction '+r'$\Delta V$'+', m/s', fontsize=10)
axes[1].set_ylabel('Number of cases', fontsize=10)
axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)



for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()
