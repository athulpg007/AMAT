# %%
from AMAT.planet import Planet
from AMAT.vehicle import Vehicle

# %%
import numpy as np
from scipy import interpolate
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.patches import Polygon

# %%
# Set up the planet and atmosphere model.
planet=Planet("MARS")
planet.loadAtmosphereModel('../../../atmdata/Mars/mars-gram-avg.dat', 0 , 1 ,2, 3)
planet.h_skip = 120e3
planet.h_low=10.0E3

# Set up the drag modulation vehicle.
vehicle=Vehicle('MarsSmallSat1', 34, 20, 0.0, np.pi*1.5**2, 0.0, 0.1, planet)

vehicle.setInitialState(120.0, 88.15, -0.71, 5.3586, 9.3778,-9.25, 0.0,0.0)
vehicle.setSolverParams(1E-6)
vehicle.setDragModulationVehicleParams(20, 7.5)

# Set up the drag modulation entry phase guidance parameters.
vehicle.setDragEntryPhaseParams(2.0, 15.0, 101, -200.0)

# Set the target orbit parameters.
vehicle.setTargetOrbitParams(200.0, 2100.0, 20.0)

# Define the path to atmospheric files to be used for the Monte Carlo simulations.
atmfiles = ['../../../atmdata/Mars/LAT00N-N1000.txt']

# Set up the Monte Carlo simulation for drag modulation.
# NPOS = 156, NMONTE = 1000
# Target EFPA = -12.05 deg
# EFPA 1-sigma error = +/- 0.067 deg
# Nominal beta_1 = 66.4 kg/m2
# beta_1 1-sigma = 0.0
# guidance time step for entry = 1.0s (Freq. = 1 Hz)
# guidance time step after jettison = 1.0 s
# max. solver time step = 0.1 s
# max. time used by solver = 2400 s

vehicle.setupMonteCarloSimulationD(156, 1000, atmfiles, 0 , 1, 2, 3, 4, True,
                                   -9.25,  0.0666, 20.0, 0.0,
                                    1.0, 1.0, 0.1, 2400.0)
# Run 200 trajectories
vehicle.runMonteCarloD2(100, '../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1')
# Out:
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 1, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 69, EFPA: -9.27, SIGMA: 2.09, APO : 1958.71
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 2, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 587, EFPA: -9.33, SIGMA: 0.07, APO : 2042.61
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 3, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 242, EFPA: -9.24, SIGMA: -0.45, APO : 2311.86
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 4, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 150, EFPA: -9.29, SIGMA: -0.57, APO : 2294.84
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 5, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 661, EFPA: -9.21, SIGMA: 0.29, APO : 2113.20
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 6, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 231, EFPA: -9.17, SIGMA: 0.05, APO : 2095.82
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 7, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 84, EFPA: -9.32, SIGMA: -0.76, APO : 2151.05
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 8, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 91, EFPA: -9.17, SIGMA: 0.90, APO : 2197.85
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 9, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 339, EFPA: -9.23, SIGMA: 1.19, APO : 2106.25
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 10, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 87, EFPA: -9.28, SIGMA: 1.08, APO : 1803.15
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 11, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 418, EFPA: -9.30, SIGMA: 1.29, APO : 1699.64
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 12, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 372, EFPA: -9.21, SIGMA: -0.12, APO : 2152.81
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 13, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 628, EFPA: -9.29, SIGMA: -0.69, APO : 2276.94
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 14, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 786, EFPA: -9.27, SIGMA: 0.28, APO : 1951.43
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 15, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #:
PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 662, EFPA: -9.25, SIGMA: 0.52, APO : 2167.68
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 89, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 403, EFPA: -9.39, SIGMA: 0.87, APO : 1789.38
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 90, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 262, EFPA: -9.30, SIGMA: 0.50, APO : 2198.92
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 91, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 567, EFPA: -9.29, SIGMA: 0.14, APO : 2316.83
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 92, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 353, EFPA: -9.24, SIGMA: -0.52, APO : 2031.00
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 93, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 406, EFPA: -9.26, SIGMA: 0.76, APO : 1948.15
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 94, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 103, EFPA: -9.39, SIGMA: 0.09, APO : 2545.98
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 95, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 756, EFPA: -9.30, SIGMA: 0.58, APO : 1925.75
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 96, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 137, EFPA: -9.13, SIGMA: 0.01, APO : 2324.71
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 97, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 2, EFPA: -9.40, SIGMA: -1.22, APO : 1862.07
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 98, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 339, EFPA: -9.24, SIGMA: 0.17, APO : 2144.47
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 99, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 3, EFPA: -9.18, SIGMA: 0.16, APO : 2285.20
# BATCH :../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1, RUN #: 100, PROF: ../../../atmdata/Mars/LAT00N-N1000.txt, SAMPLE #: 13, EFPA: -9.23, SIGMA: -1.19, APO : 2015.73

# %%
p1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/terminal_periapsis_arr.txt')
x1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/terminal_apoapsis_arr.txt')
y1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/acc_net_g_max_arr.txt')
z1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/q_stag_max_arr.txt')
h1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/heatload_max_arr.txt')
u1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/periapsis_raise_DV_arr.txt')
v1  = np.loadtxt('../../../data/acta-astronautica/smallsat-mission-concepts/mars/MCBX1/apoapsis_raise_DV_arr.txt')

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].hist(x1, bins=10, color='xkcd:periwinkle')
axes[0].set_xlabel('Apoapsis altitude x, km', fontsize=10)
axes[0].set_ylabel('Number of cases', fontsize=10)

axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)


axes[1].plot(p1, x1, 'bo', markersize=5, mfc='None')

axes[1].set_xlabel('Periapsis altitude, km',fontsize=10)
axes[1].set_ylabel('Apoapsis altitude, km', fontsize=10)


axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)

for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].plot(y1, z1, 'ro', markersize=5, mfc='None')
axes[0].set_xlabel('Peak deceleration, Earth g', fontsize=10)
axes[0].set_ylabel('Peak stagnation-point heat rate, '+r'$W/cm^2$', fontsize=10)
axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)

axes[1].plot(z1, h1, 'go', markersize=5, mfc='None')
axes[1].set_xlabel('Peak stagnation-point heat rate, '+r'$W/cm^2$', fontsize=10)
axes[1].set_ylabel('Peak stagnation-point heat load, '+r'$kJ/cm^2$', fontsize=10)

axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)



for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize = (6.5, 3.25))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
fig.tight_layout()
plt.subplots_adjust(wspace=0.30)

axes[0].hist(u1, bins=10, color='xkcd:periwinkle')
axes[0].set_xlabel('Periapse raise '+r'$\Delta V$'+', m/s', fontsize=10)
axes[0].set_ylabel('Number of cases', fontsize=10)
axes[0].tick_params(direction='in')
axes[0].yaxis.set_ticks_position('both')
axes[0].xaxis.set_ticks_position('both')
axes[0].tick_params(axis='x',labelsize=10)
axes[0].tick_params(axis='y',labelsize=10)

axes[1].hist(np.abs(v1), bins=10, color='xkcd:orange')
axes[1].set_xlabel('Apoapsis correction '+r'$\Delta V$'+', m/s', fontsize=10)
axes[1].set_ylabel('Number of cases', fontsize=10)
axes[1].tick_params(direction='in')
axes[1].yaxis.set_ticks_position('both')
axes[1].xaxis.set_ticks_position('both')
axes[1].tick_params(axis='x',labelsize=10)
axes[1].tick_params(axis='y',labelsize=10)



for ax in axes:
    ax.xaxis.set_tick_params(direction='in', which='both')
    ax.yaxis.set_tick_params(direction='in', which='both')
    ax.xaxis.set_tick_params(width=1, length=8)
    ax.yaxis.set_tick_params(width=1, length=8)
    ax.xaxis.set_tick_params(width=1, length=6, which='minor')
    ax.yaxis.set_tick_params(width=1, length=6, which='minor')
    ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)
    ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
    ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.0)

    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)

plt.show()
