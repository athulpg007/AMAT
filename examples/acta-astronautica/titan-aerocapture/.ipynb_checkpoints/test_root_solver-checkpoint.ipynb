# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# %%
def compute_E(e, M):
    root = optimize.newton(lambda E: E - e*np.sin(E) - M, x0=M, rtol=1e-6)
    return root

# %%
compute_E(0.25, np.pi)
# Out:
# 3.141592653589793

# %%
M_array = np.linspace(0, 2*np.pi, 101)

E1_array = np.array([])
E2_array = np.array([])
E3_array = np.array([])

for M in M_array:
    E1 = compute_E(0.00, M)
    E2 = compute_E(0.50, M)
    E3 = compute_E(0.99, M)
    E1_array = np.append(E1_array, E1)
    E2_array = np.append(E2_array, E2)
    E3_array = np.append(E3_array, E3)

# %%
plt.figure(figsize=(8,8))
plt.plot(E1_array, M_array, 'r--')
plt.plot(E2_array, M_array, 'g--')
plt.plot(E3_array, M_array, 'b--')
plt.show()

# %%
def compute_true_anomaly(e, E):
    return 2*np.arctan(np.sqrt((1+e)/(1-e))*np.tan(E/2))

# %%
theta_star = compute_true_anomaly(0.5, E2_array)

# %%
theta_star
# Out:
# array([ 0.00000000e+00,  2.16522725e-01,  4.26530917e-01,  6.24781762e-01,
#         8.08001637e-01,  9.74868720e-01,  1.12554343e+00,  1.26109128e+00,
#         1.38300749e+00,  1.49290195e+00,  1.59232236e+00,  1.68267121e+00,
#         1.76517831e+00,  1.84090237e+00,  1.91074601e+00,  1.97547544e+00,
#         2.03574048e+00,  2.09209290e+00,  2.14500250e+00,  2.19487070e+00,
#         2.24204187e+00,  2.28681279e+00,  2.32944038e+00,  2.37014806e+00,
#         2.40913110e+00,  2.44656088e+00,  2.48258854e+00,  2.51734796e+00,
#         2.55095829e+00,  2.58352597e+00,  2.61514657e+00,  2.64590621e+00,
#         2.67588285e+00,  2.70514739e+00,  2.73376450e+00,  2.76179353e+00,
#         2.78928908e+00,  2.81630167e+00,  2.84287822e+00,  2.86906251e+00,
#         2.89489559e+00,  2.92041610e+00,  2.94566064e+00,  2.97066400e+00,
#         2.99545946e+00,  3.02007900e+00,  3.04455352e+00,  3.06891304e+00,
#         3.09318691e+00,  3.11740395e+00, -3.14159265e+00, -3.11740395e+00,
#        -3.09318691e+00, -3.06891304e+00, -3.04455352e+00, -3.02007900e+00,
#        -2.99545946e+00, -2.97066400e+00, -2.94566064e+00, -2.92041610e+00,
#        -2.89489559e+00, -2.86906251e+00, -2.84287822e+00, -2.81630167e+00,
#        -2.78928908e+00, -2.76179353e+00, -2.73376450e+00, -2.70514739e+00,
